# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Configuration
index_file = "/data1/dnicho26/EMG_DATASET/processed/index.csv"
output_dir = "/data1/dnicho26/Thesis/AI-Assisted-Gait-Restoration-for-Disabled-Individuals/figures/signals"
os.makedirs(output_dir, exist_ok=True)

# Load the index file
index_df = pd.read_csv(index_file)

# Load a sample CSV file from the processed dataset
sample_file = index_df.iloc[0]['emg_file']  # Assuming the column contains paths
print(f"Loading sample file: {sample_file}")
# Out:
# Loading sample file: /data1/dnicho26/EMG_DATASET/processed/6/treadmill/1740009667.6738532.csv

# %%
df = pd.read_csv(sample_file)

df = df.loc[:, ~df.columns.str.contains('Unnamed', case=False)]  # Remove unnamed columns

# %%
df.head()
# Out:
#            time  sensor 0 EMG 1 (1259.259 Hz)  sensor 0 ACC X (148.148 Hz)  \
# 0  1.740010e+09                       0.28493                       0.0014
# 1  1.740010e+09                       0.28493                       0.0014
# 2  1.740010e+09                       0.28493                       0.0014
# 3  1.740010e+09                       0.28493                       0.0014
# 4  1.740010e+09                       0.28493                       0.0014
#
#    sensor 0 ACC Y (148.148 Hz)  sensor 0 ACC Z (148.148 Hz)  \
# 0                      0.25395                      0.02062
# 1                      0.25395                      0.02062
# 2                      0.25395                      0.02062
# 3                      0.25395                      0.02062
# 4                      0.25395                      0.02062
#
#    sensor 0 GYRO X (148.148 Hz)  sensor 0 GYRO Y (148.148 Hz)  \
# 0                      -0.01718                       0.00556
# ...
